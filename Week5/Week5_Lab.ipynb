# %% [markdown]
# # Week 5 Lab: Algorithm Analysis and Search Implementations
# This lab is part of the OOPs+DSA course (M.Tech Level). It is designed to be completed in 2–3 hours and requires in-depth knowledge of time complexity, linear search, and binary search. You will implement, analyze, and benchmark different search techniques.
#
# ## Learning Objectives
# - Analyze and compare algorithmic complexity (time and space).
# - Implement linear and binary search algorithms.
# - Benchmark algorithms and analyze their practical performance.
# - Explore edge cases and limitations.
# - Apply theory to real-world-like search scenarios.
#
# ---

# %% [markdown]
# ## 1. Setup and Data Preparation

# %%
import random
import time
import matplotlib.pyplot as plt

# Utility: Generate random dataset
def generate_dataset(size, sorted_data=False):
    data = random.sample(range(size * 10), size)
    return sorted(data) if sorted_data else data

# Dataset sizes to test
sizes = [10**3, 10**4, 10**5, 10**6]

# %% [markdown]
# ## 2. Implement Linear and Binary Search

# %%
def linear_search(arr, key):
    for i, val in enumerate(arr):
        if val == key:
            return i
    return -1

def binary_search(arr, key):
    low, high = 0, len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == key:
            return mid
        elif arr[mid] < key:
            low = mid + 1
        else:
            high = mid - 1
    return -1

# %% [markdown]
# ## 3. Benchmarking and Visualization
# Compare the performance of Linear Search and Binary Search across various dataset sizes.

# %%
def benchmark_search(search_fn, arr, key):
    start = time.time()
    search_fn(arr, key)
    return time.time() - start

results = {"size": [], "linear": [], "binary": []}

for size in sizes:
    data_unsorted = generate_dataset(size, sorted_data=False)
    data_sorted = sorted(data_unsorted)
    key = data_unsorted[-1]  # Worst-case key

    t_linear = benchmark_search(linear_search, data_unsorted, key)
    t_binary = benchmark_search(binary_search, data_sorted, key)

    results["size"].append(size)
    results["linear"].append(t_linear)
    results["binary"].append(t_binary)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(results["size"], results["linear"], label='Linear Search', marker='o')
plt.plot(results["size"], results["binary"], label='Binary Search', marker='s')
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Input Size (log scale)")
plt.ylabel("Time Taken (seconds, log scale)")
plt.title("Search Algorithm Benchmark")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4. Complex and Practical Exercises
# ### 4.1: Search on File-based Datasets
# Write a function that loads a file containing a list of integers (one per line), and performs both linear and binary search for a user-specified key. Time both searches and compare.

# %%
# TODO: Implement this yourself
def search_file_dataset(file_path, key):
    pass  # read file, convert to list, apply searches

# %% [markdown]
# ### 4.2: Adaptive Hybrid Search
# Design and implement a hybrid search algorithm that decides at runtime whether to use linear or binary search based on data size and distribution.
# - For small datasets, prefer linear search.
# - For sorted datasets above threshold, prefer binary search.
# - Benchmark this adaptive method and compare against traditional approaches.

# %%
# TODO: Implement hybrid search logic
def hybrid_search(arr, key):
    # Example: Threshold size = 1000
    if len(arr) < 1000:
        return linear_search(arr, key)
    else:
        return binary_search(sorted(arr), key)

# %% [markdown]
# ## 5. Summary and Reflections
# - What are the trade-offs between linear and binary search?
# - How does actual runtime performance differ from theoretical expectations?
# - In what real-world scenarios would linear search be preferred over binary search?
# - How would you design an optimal search system for very large datasets stored across networked machines?
#
# ## Optional Challenge (Extra Credit)
# Implement interpolation search and test it on datasets where values are uniformly distributed. Compare it against binary search.
